# %%
# Load UCI census and convert to json for sending to the visualization
import pandas as pd
features = ["Team", "Sprint #", "Start Date", "End Date", "Working Days", "Leaves", "Story Points", "Time Taken (Mins)", "All Committed Storypoints", "All Committed User Stories", "All Added Later", "All Added Later Stories", "All Actual Storypoints (Velocity)", "All Completed Stories", "All Total Storypoints", "All Removed Story Points", "All Average Velocity", "Spillover - All", "All Accuracy", "All Vertical Line 1", "Cyb Committed Storypoints", "Cyb Committed User Stories", "Cyb Added Later", "Cyb Added Later Stories", "Cyb Actual Storypoints (Velocity)", "Cyb Completed Stories", "Cyb Total Storypoints", "Cyb Removed Story Points", "Cyb Average Velocity", "Spillover - Cyb", "Cyb Accuracy", "Cyb Vertical Line 2", "US Committed Storypoints", "US Added Later", "US Actual Storypoints (Velocity)", "US Total Storypoints", "US Removed Story Points", "US Average Velocity", "US Spillover - US", "US Accuracy", "US Vertical Line 3", "Cyb Team Size", "Cyb Available Hours", "Cyb Burnt Hours", "Cyb Productivity"]
jsonstr = pd.read_csv(
    "C:\\Users\\dhavalma\\facets\\Custom_Project_Data-Filebound.csv",
    names=features,
    sep=r'\s*,\s*',
    engine='python',
    skiprows=[0],
    na_values="?").to_json(orient='records')

# %%
# Display the Dive visualization for this data
from IPython.core.display import display, HTML

HTML_TEMPLATE = """<link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
# <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="600"></facets-dive>
#         <script>
#           var data = [{"Team":"Jaeger","Sprint #":"FBM1","Start Date":"10\/12\/2015","End Date":"10\/27\/2015","Working Days":11,"Leaves":3.0,"Story Points":44.0,"Time Taken (Mins)":13905,"All Committed Storypoints":121,"All Committed User Stories":null,"All Added Later":126,"All Added Later Stories":null,"All Actual Storypoints (Velocity)":217,"All Completed Stories":null,"All Total Storypoints":247,"All Removed Story Points":30,"All Average Velocity":211.0,"Spillover - All":0,"All Accuracy":"1.79338843","All Vertical Line 1":"179%","Cyb Committed Storypoints":80,"Cyb Committed User Stories":null,"Cyb Added Later":84,"Cyb Added Later Stories":null,"Cyb Actual Storypoints (Velocity)":141.0,"Cyb Completed Stories":null,"Cyb Total Storypoints":164.0,"Cyb Removed Story Points":23,"Cyb Average Velocity":106.0,"Spillover - Cyb":0,"Cyb Accuracy":"1.7625","Cyb Vertical Line 2":"FBM1","US Committed Storypoints":41.0,"US Added Later":42.0,"US Actual Storypoints (Velocity)":76.0,"US Total Storypoints":83.0,"US Removed Story Points":7,"US Average Velocity":105,"US Spillover - US":0,"US Accuracy":"1.853658537","US Vertical Line 3":"FBM1","Cyb Team Size":1.976190476,"Cyb Available Hours":124.0,"Cyb Burnt Hours":232.0,"Cyb Productivity":"187%"},{"Team":"Pirate","Sprint #":"FBF1","Start Date":"10\/19\/2015","End Date":"11\/3\/2015","Working Days":11,"Leaves":0.0,"Story Points":40.0,"Time Taken (Mins)":4230,"All Committed Storypoints":0,"All Committed User Stories":null,"All Added Later":0,"All Added Later Stories":null,"All Actual Storypoints (Velocity)":0,"All Completed Stories":null,"All Total Storypoints":0,"All Removed Story Points":0,"All Average Velocity":0.0,"Spillover - All":0,"All Accuracy":"0","All Vertical Line 1":"0%","Cyb Committed Storypoints":0,"Cyb Committed User Stories":null,"Cyb Added Later":0,"Cyb Added Later Stories":null,"Cyb Actual Storypoints (Velocity)":0.0,"Cyb Completed Stories":null,"Cyb Total Storypoints":0.0,"Cyb Removed Story Points":0,"Cyb Average Velocity":0.0,"Spillover - Cyb":0,"Cyb Accuracy":"0","Cyb Vertical Line 2":"FBF1","US Committed Storypoints":0.0,"US Added Later":0.0,"US Actual Storypoints (Velocity)":0.0,"US Total Storypoints":0.0,"US Removed Story Points":0,"US Average Velocity":0,"US Spillover - US":0,"US Accuracy":"0","US Vertical Line 3":"FBF1","Cyb Team Size":0.0,"Cyb Available Hours":0.0,"Cyb Burnt Hours":71.0,"Cyb Productivity":"#DIV\/0!"},{"Team":"Jaeger","Sprint #":"FBM2","Start Date":"10\/26\/2015","End Date":"11\/23\/2015","Working Days":19,"Leaves":17.5,"Story Points":30.0,"Time Taken (Mins)":4145,"All Committed Storypoints":0,"All Committed User Stories":null,"All Added Later":0,"All Added Later Stories":null,"All Actual Storypoints (Velocity)":0,"All Completed Stories":null,"All Total Storypoints":0,"All Removed Story Points":0,"All Average Velocity":0.0,"Spillover - All":0,"All Accuracy":"0","All Vertical Line 1":"0%","Cyb Committed Storypoints":0,"Cyb Committed User Stories":null,"Cyb Added Later":0,"Cyb Added Later Stories":null,"Cyb Actual Storypoints (Velocity)":0.0,"Cyb Completed Stories":null,"Cyb Total Storypoints":0.0,"Cyb Removed Story Points":0,"Cyb Average Velocity":0.0,"Spillover - Cyb":0,"Cyb Accuracy":"0","Cyb Vertical Line 2":"FBM2","US Committed Storypoints":0.0,"US Added Later":0.0,"US Actual Storypoints (Velocity)":0.0,"US Total Storypoints":0.0,"US Removed Story Points":0,"US Average Velocity":0,"US Spillover - US":0,"US Accuracy":"0","US Vertical Line 3":"FBM2","Cyb Team Size":0.0,"Cyb Available Hours":-116.0,"Cyb Burnt Hours":69.0,"Cyb Productivity":"-60%"},{"Team":"Pirate","Sprint #":"FBF2","Start Date":"11\/2\/2015","End Date":"11\/16\/2015","Working Days":9,"Leaves":0.0,"Story Points":27.0,"Time Taken (Mins)":5520,"All Committed Storypoints":0,"All Committed User Stories":null,"All Added Later":0,"All Added Later Stories":null,"All Actual Storypoints (Velocity)":0,"All Completed Stories":null,"All Total Storypoints":0,"All Removed Story Points":0,"All Average ...
